# %%
import sqlalchemy
import alchy
import datetime as dt
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from cg.store import Store, models
from cg.store.api.core import CoreHandler

# %%
class MockStore(alchy.Manager, CoreHandler):
    def __init__(self):
        super(MockStore, self).__init__(
            config={
                'SQLALCHEMY_DATABASE_URI': 'sqlite:///:memory:'
            }, 
            Model=models.Model)
        self.create_all()
store_api = MockStore()

# %%
family3 = models.Family(
    id=3,
    internal_id="bravepíkachu", 
    name="test03", 
    priority=2, 
    customer_id=1,
    panels=[""],
    action="analyze",
    comment="balsamic+single+panel")


family4 = models.Family(
    id=4,
    internal_id="wisesquirtle", 
    name="test04", 
    priority=3, 
    customer_id=1,
    panels=[""],
    action="analyze",
    comment="balsamic+single+wgs")

# %%
#WGS samples

family1 = models.Family(
    id=1,
    internal_id="timidbulbasaur", 
    name="test01", 
    priority=0, 
    customer_id=1,
    panels=[""],
    action="analyze",
    comment="balsamic+paired+panel"
)

sample11 = models.Sample(
    id=11,
    name="111QWEA1",
    internal_id="timidbulbasaur",
    priority=0,
    is_tumour=True,
    data_analysis="BALSAMIC",
    sex="unknown",
    customer_id=1,
    application_version_id=1,
)

sample12 = models.Sample(
    id=12,
    name="111QWEA2",
    internal_id="timidbulbasaur",
    priority=0,
    is_tumour=False,
    data_analysis="BALSAMIC",
    sex="unknown",
    customer_id=1,
    application_version_id=1
)

familysample11 = models.FamilySample(
    status="affected",
    family_id=1,
    sample_id=11,   
)

familysample12 = models.FamilySample(
    status="unaffected",
    family_id=1,
    sample_id=12,   
)

# %%
# Panel paired 

family2 = models.Family(
    id=2,
    internal_id="restlesscharmander", 
    name="test02", 
    priority=1, 
    customer_id=1,
    panels=[""],
    action="analyze",
    comment="balsamic+paired+wgs")

sample21 = models.Sample(
    id=21,
    name="222QWEA1",
    internal_id="restlesscharmander",
    priority=0,
    is_tumour=True,
    data_analysis="BALSAMIC",
    sex="unknown",
    customer_id=1,
    application_version_id=2,
)

sample22 = models.Sample(
    id=22,
    name="222QWEA2",
    internal_id="restlesscharmander",
    priority=0,
    is_tumour=False,
    data_analysis="BALSAMIC",
    sex="unknown",
    customer_id=1,
    application_version_id=2
)

familysample21 = models.FamilySample(
    status="affected",
    family_id=2,
    sample_id=21,   
)

familysample22 = models.FamilySample(
    status="unaffected",
    family_id=2,
    sample_id=22,   
)

# %%
application_wgs = models.Application(
    id=1,
    tag="WGSPCFC060",
    prep_category="wgs",
    is_external=False,
    description="90XWGS MOCK",
    is_accredited=True,
    percent_kth=80,
)

application_wes = models.Application(
    id=2,
    tag="EXOSXTR150",
    prep_category="wes",
    is_external=False,
    description="250XWES MOCK",
    is_accredited=True,
    percent_kth=80,
)

application_tgs = models.Application(
    id=3,
    tag="MHPSXTR025",
    prep_category="tgs",
    is_external=False,
    description="200XTGS MOCK",
    is_accredited=True,
    percent_kth=80,
)

application_wts = models.Application(
    id=4,
    tag="RNLPOAR075",
    prep_category="wts",
    is_external=False,
    description="RNAWTS MOCK",
    is_accredited=True,
    percent_kth=80,
)

application_mic = models.Application(
    id=5,
    tag="MWRNXTR003",
    prep_category="mic",
    is_external=False,
    description="MIC MOCK",
    is_accredited=True,
    percent_kth=55,
)

application_rml = models.Application(
    id=6,
    tag="RMLP15R300",
    prep_category="rml",
    is_external=False,
    description="RML MOCK",
    is_accredited=True,
    percent_kth=80,
)

# %%
application_version_wgs = models.ApplicationVersion(
    id=1,
    version=3,
    valid_from=dt.datetime.now(),
    application_id=1,    
)
application_version_wes = models.ApplicationVersion(
    id=2,
    version=3,
    valid_from=dt.datetime.now(),
    application_id=2,    
)
application_version_tgs = models.ApplicationVersion(
    id=3,
    version=2,
    valid_from=dt.datetime.now(),
    application_id=3,    
)
application_version_wts = models.ApplicationVersion(
    id=4,
    version=2,
    valid_from=dt.datetime.now(),
    application_id=4,    
)
application_version_mic = models.ApplicationVersion(
    id=5,
    version=1,
    valid_from=dt.datetime.now(),
    application_id=5,    
)
application_version_rml = models.ApplicationVersion(
    id=6,
    version=1,
    valid_from=dt.datetime.now(),
    application_id=6,    
)

# %%
customer_group1 = models.CustomerGroup(
    id=1,
    internal_id="tester007",
    name="BALSAMIC TESTER",
)
customer1 = models.Customer(
    id=1,
    internal_id="tester007",
    name="BALSAMIC TESTER",
    priority="research",
    customer_group_id=1,
    project_account_ki=1,
    invoice_address="SciLifeLab",
    invoice_reference="REF1",
)
new_user = models.User(
    name="Martin Martinaise",
    email="test.user@ki.se",
    is_admin=False,
    customer_id=1,
)

# %%
bed1_name = "BalsamicBed1"
bed1_filename = "balsamic_bed_1.bed"
bed1 = store_api.add_bed(name=bed1_name)
store_api.add_commit(bed1)
version1 = store_api.add_bed_version(bed=bed1, version=1, filename=bed1_filename, shortname=bed1_name)
store_api.add_commit(version1)

#Create BED2 version 1
bed2_name = "BalsamicBed2"
bed2_filename = "balsamic_bed_2.bed"
bed2 = store_api.add_bed(name=bed2_name)
store_api.add_commit(bed2)
version2 = store_api.add_bed_version(bed=bed2, version=1, filename=bed2_filename, shortname=bed2_name)
store_api.add_commit(version2)

# %%
store_api.add_commit(version2)

# %%
store_api.application()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-301-bba59225645f> in <module>
# ----> 1 store_api.application()
#
# TypeError: application() missing 1 required positional argument: 'tag'

# %%
store_api.rollback()
store_api.add_commit(family1, sample11, sample12, family1sample11, family1sample12)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~/anaconda3/envs/CG/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1257                     self.dialect.do_executemany(
# -> 1258                         cursor, statement, parameters, context
#    1259                     )
#
# ~/anaconda3/envs/CG/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     589     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 590         cursor.executemany(statement, parameters)
#     591
#
# IntegrityError: NOT NULL constraint failed: sample.application_version_id
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
store_api.user("test.user@ki.se")
# Out:
# <User(id=1, name='Martin Martinaise', email='test.user@ki.se', is_admin=False, customer_id=1)>

# %%
from genologics.lims
